# %% [markdown]
# ## Load Data

# %%
import json
import pandas as pd

path = '/Users/darrenlee/Downloads/dataset_glassdoor-jobs-scraper_2022-03-07_01-35-43-133.csv'
df1 = pd.read_csv(path)

path2 = '/Users/darrenlee/Downloads/dataset_glassdoor-jobs-scraper_2022-03-07_01-47-52-311.csv'
df2 = pd.read_csv(path2)
df = pd.concat([df1, df2], axis=0)
df.shape
# Out:
# (69, 36)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69 entries, 0 to 31
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   companyDetails/careerOpportunitiesRating      0 non-null      float64
#  1   companyDetails/ceoName                        0 non-null      float64
#  2   companyDetails/ceoName/__typename             51 non-null     object
#  3   companyDetails/ceoName/name                   50 non-null     object
#  4   companyDetails/ceoName/photoUrl               40 non-null     object
#  5   companyDetails/companyRating                  0 non-null      float64
#  6   companyDetails/compensationAndBenefitsRating  0 non-null      float64
#  7   companyDetails/cultureAndValuesRating         0 non-null      float64
#  8   companyDetails/headquarters                   58 non-null     object
# ...

# %%
df[['jobTitle', 'jobLocation', 'employerName', 'companyDetails/name', 'jobDetails','companyDetails/size',
    'salary/min', 'salary/max', 'salary/source']]
# Out:
#                                     jobTitle        jobLocation  \
# 0        Senior Data Scientist - Remote (SF)  San Francisco, CA
# 1   Senior Data Scientist - Ads Optimization  San Francisco, CA
# 2                             Data Scientist     Burlingame, CA
# 3        Data Scientist (Banking/Financials)         California
# 4                             Data Scientist     Burlingame, CA
# ..                                       ...                ...
# 27                            Data Scientist       Bellevue, WA
# 28                            Data Scientist       Carlsbad, CA
# 29                   Data Scientist - Remote             Remote
# 30                            Data Scientist         Dayton, OH
# 31         Data Scientist (Machine Learning)             Remote
#
#                           employerName                 companyDetails/name  \
# 0                             RunBuggy                            RunBuggy
# ...

# %%
df['salary/min'].describe()
# Out:
# count        64.00000
# mean     105450.81250
# std       35082.09534
# min       58756.00000
# 25%       80660.75000
# 50%       93071.50000
# 75%      124850.00000
# max      215000.00000
# Name: salary/min, dtype: float64

# %%
df.groupby("salary/source")['salary/min'].describe()
# Out:
#                    count          mean           std      min       25%  \
# salary/source
# EMPLOYER_PROVIDED   32.0  126150.78125  37404.086195  60000.0  96597.25
# ESTIMATED           32.0   84750.84375  14748.594531  58756.0  76637.75
#
#                         50%        75%       max
# salary/source
# EMPLOYER_PROVIDED  124900.0  150000.00  215000.0
# ESTIMATED           85754.0   92915.25  120167.0

# %%
df.groupby("salary/source")['salary/max'].describe()
# Out:
#                    count          mean           std       min       25%  \
# salary/source
# EMPLOYER_PROVIDED   32.0  154689.31250  47009.492389   65000.0  120000.0
# ESTIMATED           32.0  164620.78125  27933.634021  101924.0  148459.5
#
#                         50%       75%       max
# salary/source
# EMPLOYER_PROVIDED  150000.0  188875.0  259000.0
# ESTIMATED          163546.0  186241.5  219655.0

# %%
df['companyDetails/size'].value_counts(dropna=False)
# Out:
# 10000+ Employees           18
# 51 to 200 Employees        12
# NaN                        11
# 1 to 50 Employees           9
# 501 to 1000 Employees       6
# 1001 to 5000 Employees      4
# 201 to 500 Employees        4
# Unknown                     3
# 5001 to 10000 Employees     2
# Name: companyDetails/size, dtype: int64
